# %%
from baselines.common import plot_util as pu
import matplotlib.pyplot as plt
import numpy as np
results = pu.load_results('./log_showdown/1v1_meta');
print(len(results))
# Out:
# 1

# %%
r = results[0]
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=10))

# %%
pu.plot_results(results, average_group=True)
# Out:
# (<Figure size 432x864 with 2 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcdf2e87d90>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcdf2bd6250>]],
#        dtype=object))
